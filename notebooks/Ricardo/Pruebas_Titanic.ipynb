# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, QuantileTransformer, RobustScaler

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
CAT_COLUMN_NAMES = ['family_size', 'embarked', 'sex', 'pclass', 'title', 'is_alone']
CONT_COLUMN_NAMES = ['age', 'ticket_price']
QUANTILE_SIZE = 10
TAR_COLUMN_NAMES = ['survived']

# %%
x_train, y_train = fetch_openml("titanic", version=1, as_frame=True, return_X_y=True)

# Some features considered irrelevant are dropped from the beginning
x_train.drop(['boat', 'body', 'home.dest'], axis=1, inplace=True)
x_train.rename(columns={'fare': 'ticket_price'}, inplace=True)

# Synthetic features are calculated out of the given ones
x_train['family_size'] = x_train['parch'] + x_train['sibsp']
x_train['is_alone'] = np.where(x_train['family_size'] > 1, 0, 1)

# Title feature can be extracted from the name
x_train['title'] = x_train['name'].str.split(", ", expand=True)[1].str.split(".", expand=True)[0]
x_train.loc[x_train['title'] == 'Miss', 'title'] = 'Mrs'
x_train.loc[x_train['title'] == 'Master', 'title'] = 'Mr'
x_train.loc[(x_train['title'] != 'Mrs') & (x_train['title'] != 'Mr'), 'title'] = 'rare'

# Imputación de nulos: más frecuente -> variables categóricas & 'k-vecinos=5 para las continuas'
cat_transformer = Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))])
num_transformer = Pipeline(steps=[('imputer', KNNImputer(n_neighbors=5))])
preprocessor = ColumnTransformer(
    transformers=[('num', num_transformer, CONT_COLUMN_NAMES), ('cat', cat_transformer, CAT_COLUMN_NAMES)])
preprocessor.fit(x_train)
x_train_prepro = preprocessor.transform(x_train)


# Once the features have been preprocessed, the target column is vertically appended
concat_train_prepro = np.concatenate((x_train_prepro, np.expand_dims(y_train.values, axis=1)), axis=1).tolist()

# Build Datafrane with Features + y_true
df_train = pd.DataFrame(concat_train_prepro, columns=CONT_COLUMN_NAMES + CAT_COLUMN_NAMES + TAR_COLUMN_NAMES)
columns_features = df_train.columns.drop('survived').to_list()

# family_size transform
df_train['family_size'] = df_train['family_size'].apply(lambda x: 'Family_1' if x <= 1
                                                        else ('Family_2' if (x ==2)
                                                              else ('Family_3_5' if (x >2 and x <= 5)
                                                                    else 'Family_upper_5')))

df_train.head(15)
# Out:
#         age  ticket_price family_size embarked     sex  pclass title  \
# 0   29.0000      211.3375    Family_1        S  female     1.0   Mrs
# 1    0.9167      151.5500  Family_3_5        S    male     1.0    Mr
# 2    2.0000      151.5500  Family_3_5        S  female     1.0   Mrs
# 3   30.0000      151.5500  Family_3_5        S    male     1.0    Mr
# 4   25.0000      151.5500  Family_3_5        S  female     1.0   Mrs
# 5   48.0000       26.5500    Family_1        S    male     1.0    Mr
# 6   63.0000       77.9583    Family_1        S  female     1.0   Mrs
# 7   39.0000        0.0000    Family_1        S    male     1.0    Mr
# 8   53.0000       51.4792    Family_2        S  female     1.0   Mrs
# 9   71.0000       49.5042    Family_1        C    male     1.0    Mr
# 10  47.0000      227.5250    Family_1        C    male     1.0  rare
# 11  18.0000      227.5250    Family_1        C  female     1.0   Mrs
# 12  24.0000       69.3000    Family_1        C  female     1.0  rare
# 13  26.0000       78.8500    Family_1        S  female     1.0   Mrs
# 14  80.0000       30.0000    Family_1        S    male     1.0    Mr
#
#     is_alone survived
# 0          1        1
# 1          0        1
# 2          0        0
# 3          0        0
# 4          0        0
# 5          1        1
# 6          1        1
# 7          1        0
# 8          0        1
# 9          1        0
# 10         1        0
# 11         1        1
# 12         1        1
# 13         1        1
# 14         1        1

# %%
# Separación de variables categoricas, continuas y target
cat = df_train[CAT_COLUMN_NAMES].values
cont = df_train[CONT_COLUMN_NAMES].values
tar = df_train['survived'].values

# OneHot enconding de las pariables categoricas
enc = OneHotEncoder()
enc.fit(cat)
cat_enc = enc.transform(cat)

# Nombre de las columnas OneHot Encoding
enc_names = CONT_COLUMN_NAMES.copy()
for col_n in CAT_COLUMN_NAMES:
    for v in pd.unique(df_train[col_n]):
        enc_names.append(col_n + '_{}'.format(v) if isinstance(v, str) else col_n + '_{:.1f}'.format(v))
enc_names.append('survived')

# Paso a DataFrame
data = np.concatenate((cont, cat_enc.toarray(), [[i] for i in tar]), axis=1)
df_ohe = pd.DataFrame(data, columns=enc_names)
df_train_features = df_ohe.drop(['survived'], axis=1)
df_train_target = df_ohe['survived'].astype('int')

# Entrenamiento y prediccion del modelo
model = RandomForestClassifier()
model.fit(df_train_features.values, df_train_target.values)
pre_prediction = model.predict(df_train_features.values)
print('INFO: Train accuracy: {:.4f}'.format(accuracy_score(df_train_target.values, pre_prediction)))

# Target column is replaced in the ORIGINAL dataset (not the one with the dummy variables) by the prediction column
df_predict = df_train
df_predict['y_true'] = df_predict['survived']
df_predict['y_predict'] = pre_prediction
df_predict_targets = pd.get_dummies(df_predict['y_predict'], prefix='survived')
df_predict = pd.concat([df_predict.drop(['survived'], axis=1), df_predict_targets], axis=1)

# replace predictions targets names
df_predict.rename(columns={'survived_0': 'NO_SURVIVED', 'survived_1': 'SURVIVED'}, inplace=True)
df_predict.sample(10)
# Out:
# INFO: Train accuracy: 0.9679
#        age  ticket_price family_size embarked     sex  pclass title  is_alone  \
# 171   46.0       26.0000    Family_1        S    male     1.0    Mr         1
# 184   35.3       27.7208    Family_1        C    male     1.0    Mr         1
# 575   27.0       21.0000    Family_1        S  female     2.0   Mrs         1
# 1160  50.0        8.0500    Family_1        S    male     3.0    Mr         1
# 441   55.0       16.0000    Family_1        S  female     2.0   Mrs         1
# 98    48.0      106.4250    Family_1        C  female     1.0   Mrs         1
# 458   17.0       10.5000    Family_1        S  female     2.0   Mrs         1
# 460   24.0       27.0000  Family_3_5        S  female     2.0   Mrs         0
# 802   35.6        6.9500    Family_1        Q    male     3.0    Mr         1
# 1258  29.0       15.2458    Family_2        C  female     3.0   Mrs         0
#
#      y_true  y_predict  NO_SURVIVED  SURVIVED
# 171       0          0            1         0
# 184       0          0            1         0
# 575       0          0            1         0
# 1160      0          0            1         0
# 441       1          1            0         1
# 98        1          1            0         1
# 458       1          1            0         1
# 460       1          1            0         1
# 802       0          0            1         0
# 1258      1          1            0         1

# %%
#Discretización con "criterio" de las variables age y fare
# import seaborn as sns
# sns.histplot(data=df_predict, x="age")

# Discretizamos la edad
# df_predict['age'] = df_predict['age'].apply(lambda x: 'Kids-10' if x <= 10
#                                             else ('Teenager_10_18' if (x >10 and x <= 18)
#                                                   else ('Young_18_25' if (x >18 and x <= 25)
#                                                         else ('Adult_25_65' if (x >18 and x <= 25)
#                                                               else 'Old+65'))))
# Discretizamos 
qt = QuantileTransformer(n_quantiles=5, random_state=0)
df_predict['ticket_price'] = qt.fit_transform(df_predict[['ticket_price']].values)



# df_predict.sample(10)

# %%
qt.references_
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
import numpy as np
from sklearn.preprocessing import quantile_transform
rng = np.random.RandomState(0)
X = np.sort(rng.normal(loc=0.5, scale=0.25, size=(25, 1)), axis=0)
quantile_transform(X, n_quantiles=10, random_state=0, copy=True)
# Out:
# array([[0.        ],
#        [0.09871873],
#        [0.10643612],
#        [0.11754671],
#        [0.21017437],
#        [0.21945445],
#        [0.23498666],
#        [0.32443642],
#        [0.33333333],
#        [0.41360794],
#        [0.42339464],
#        [0.46257841],
#        [0.47112236],
#        [0.49834237],
#        [0.59986536],
#        [0.63390302],
#        [0.66666667],
#        [0.68873101],
#        [0.69611125],
#        [0.81280699],
#        [0.82160354],
#        [0.88126439],
#        [0.90516028],
#        [0.99319435],
#        [1.        ]])

# %%
df_predict.sample(10)
# Out:
#        age  ticket_price     family_size embarked     sex  pclass title  \
# 710   37.0      0.245384        Family_1        Q  female     3.0   Mrs
# 1095  23.0      0.241559        Family_1        Q  female     3.0   Mrs
# 1065  21.0      0.246967        Family_1        S    male     3.0    Mr
# 861   23.0      0.251113        Family_1        S  female     3.0   Mrs
# 832   43.0      0.758120  Family_upper_5        S  female     3.0   Mrs
# 1051  33.0      0.255878        Family_1        S    male     3.0    Mr
# 973   28.6      0.239051        Family_1        S    male     3.0    Mr
# 713   21.0      0.244855        Family_1        Q    male     3.0    Mr
# 527   28.0      0.349270        Family_1        S    male     2.0    Mr
# 71    27.0      0.804830        Family_1        C    male     1.0    Mr
#
#       is_alone y_true  y_predict  NO_SURVIVED  SURVIVED
# 710          1      0          0            1         0
# 1095         1      0          0            1         0
# 1065         1      0          0            1         0
# 861          1      0          0            1         0
# 832          0      0          0            1         0
# 1051         1      0          0            1         0
# 973          1      0          0            1         0
# 713          1      0          0            1         0
# 527          1      0          0            1         0
# 71           1      0          0            1         0

# %%
from sklearn.preprocessing import KBinsDiscretizer
kbd = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='quantile')
df_predict['ticket_price5'] = qt.fit_transform(df_predict[['ticket_price']].values)
df_predict.sample(10)
# Out:
#        age  ticket_price family_size embarked     sex  pclass title  is_alone  \
# 19    36.0      0.772849    Family_1        C    male     1.0    Mr         1
# 202   36.0      0.675873    Family_1        S    male     1.0    Mr         1
# 141   45.0      0.766673    Family_1        C  female     1.0   Mrs         1
# 381   30.0      0.444567    Family_1        S  female     2.0   Mrs         1
# 182   30.0      0.789055    Family_1        C  female     1.0   Mrs         1
# 809   18.0      0.751611  Family_3_5        S    male     3.0    Mr         0
# 1096   2.0      0.598402  Family_3_5        S    male     3.0    Mr         0
# 527   28.0      0.349270    Family_1        S    male     2.0    Mr         1
# 526   29.0      0.477285    Family_1        C    male     2.0    Mr         1
# 1068  61.0      0.197494    Family_1        S    male     3.0    Mr         1
#
#      y_true  y_predict  NO_SURVIVED  SURVIVED  ticket_price2  ticket_price3  \
# 19        0          0            1         0       0.772849       0.772849
# 202       1          1            0         1       0.675873       0.675873
# 141       1          1            0         1       0.766673       0.766673
# 381       0          1            0         1       0.444567       0.444567
# 182       1          1            0         1       0.789055       0.789055
# 809       0          0            1         0       0.751611       0.751611
# 1096      0          0            1         0       0.598402       0.598402
# 527       0          0            1         0       0.349270       0.349270
# 526       1          1            0         1       0.477285       0.477285
# 1068      0          0            1         0       0.197494       0.197494
#
#       ticket_price4  ticket_price5
# 19         0.772849       0.772849
# 202        0.675873       0.675873
# 141        0.766673       0.766673
# 381        0.444567       0.444567
# 182        0.789055       0.789055
# 809        0.751611       0.751611
# 1096       0.598402       0.598402
# 527        0.349270       0.349270
# 526        0.477285       0.477285
# 1068       0.197494       0.197494

# %%
rng = np.random.RandomState(0)
X = rng.normal(loc=0.5, scale=0.25, size=(25, 1))
# X
qt = QuantileTransformer(n_quantiles=5, random_state=0)
qt.fit_transform(X)
qt.references_
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
df_predict.sample(100)
# Out:
#                  age  ticket_price     family_size embarked     sex  pclass  \
# 319           Old+65      134.5000        Family_1        C  female     1.0
# 1188     Young_18_25       16.7000        Family_2        S  female     3.0
# 317      Young_18_25       61.3792        Family_1        C    male     1.0
# 528           Old+65        0.0000        Family_1        S    male     2.0
# 1046     Young_18_25        7.8958        Family_1        S    male     3.0
# 603           Old+65       20.2500        Family_2        S  female     3.0
# 114      Young_18_25      263.0000      Family_3_5        S    male     1.0
# 62            Old+65       61.1750        Family_1        S    male     1.0
# 723           Old+65        7.7333        Family_1        Q    male     3.0
# 1240         Kids-10        8.5167        Family_1        C    male     3.0
# 987      Young_18_25        7.8792        Family_1        Q  female     3.0
# 507           Old+65       13.0000        Family_1        S    male     2.0
# 1250          Old+65        7.8958        Family_1        S    male     3.0
# 1128          Old+65        7.8958        Family_1        S    male     3.0
# 1135          Old+65        7.8958        Family_1        S    male     3.0
# 545           Old+65       21.0000      Family_3_5        S  female     2.0
# 909           Old+65        7.9250        Family_1        S    male     3.0
# 123           Old+65       79.2000        Family_2        C    male     1.0
# 623          Kids-10       31.2750  Family_upper_5        S  female     3.0
# 787   Teenager_10_18        7.7750        Family_1        S    male     3.0
# 930           Old+65        7.7500        Family_1        Q    male     3.0
# 1222          Old+65        8.6625        Family_1        C    male     3.0
# 1059          Old+65        8.0500        Family_1        S    male     3.0
# 999           Old+65        7.7500        Family_1        Q  female     3.0
# 446      Young_18_25       23.0000      Family_3_5        S  female     2.0
# 391           Old+65       27.7208        Family_1        C    male     2.0
# 858           Old+65       56.4958        Family_1        S    male     3.0
# 854           Old+65        6.8583        Family_1        Q    male     3.0
# 276           Old+65      146.5208        Family_1        C    male     1.0
# 1304  Teenager_10_18       14.4542        Family_1        C  female     3.0
# 859   Teenager_10_18        6.7500        Family_1        Q  female     3.0
# 1123     Young_18_25       22.3583        Family_2        C  female     3.0
# 398          Kids-10       32.5000        Family_2        S    male     2.0
# 1104  Teenager_10_18       39.6875      Family_3_5        S    male     3.0
# 502           Old+65       19.5000        Family_1        S  female     2.0
# 926           Old+65        7.7500        Family_1        Q    male     3.0
# 635      Young_18_25       17.8000        Family_1        S    male     3.0
# 651           Old+65        7.2250        Family_1        C    male     3.0
# 947      Young_18_25        7.2500        Family_1        S  female     3.0
# 464           Old+65       10.5000        Family_1        S    male     2.0
# 760           Old+65        9.5000        Family_1        S    male     3.0
# 110           Old+65       27.7500        Family_1        C    male     1.0
# 1297          Old+65        7.2500        Family_1        S    male     3.0
# 510   Teenager_10_18       10.5000        Family_1        S    male     2.0
# 853      Young_18_25        7.2500        Family_1        S    male     3.0
# 1178          Old+65       69.5500  Family_upper_5        S    male     3.0
# 367           Old+65       13.5000        Family_1        S    male     2.0
# 95            Old+65       81.8583        Family_2        S  female     1.0
# 430          Kids-10       33.0000        Family_1        S  female     2.0
# 1001     Young_18_25       23.2500        Family_2        Q  female     3.0
# 702      Young_18_25        7.7500        Family_1        Q  female     3.0
# 218           Old+65      108.9000        Family_1        C  female     1.0
# 318           Old+65       35.0000        Family_1        S    male     1.0
# 205           Old+65       26.5500        Family_1        S    male     1.0
# 862      Young_18_25        8.9625        Family_1        S  female     3.0
# 608           Old+65        7.2500        Family_1        S    male     3.0
# 719   Teenager_10_18        8.0500        Family_1        S    male     3.0
# 214      Young_18_25      113.2750        Family_1        C  female     1.0
# 137      Young_18_25       30.0000        Family_1        S  female     1.0
# 74            Old+65       52.0000        Family_1        S    male     1.0
# 827   Teenager_10_18       46.9000  Family_upper_5        S    male     3.0
# 175           Old+65       51.8625        Family_1        S    male     1.0
# 1287          Old+65        7.7500        Family_1        S    male     3.0
# 294           Old+65      110.8833        Family_2        C    male     1.0
# 693      Young_18_25        7.8208        Family_1        Q    male     3.0
# 199      Young_18_25       49.5042        Family_1        C  female     1.0
# 852           Old+65        7.5500        Family_1        S  female     3.0
# 0             Old+65      211.3375        Family_1        S  female     1.0
# 1005          Old+65       15.5000        Family_1        Q    male     3.0
# 753      Young_18_25        8.0500        Family_1        S    male     3.0
# 1243     Young_18_25        7.2250        Family_1        C    male     3.0
# 716           Old+65       14.4542        Family_1        C    male     3.0
# 482   Teenager_10_18       12.0000        Family_1        C  female     2.0
# 915      Young_18_25        7.5208        Family_1        S    male     3.0
# 58            Old+65       26.0000        Family_1        S    male     1.0
# 500           Old+65       26.0000        Family_1        S    male     2.0
# 402           Old+65       13.8583        Family_1        C  female     2.0
# 710           Old+65        7.7500        Family_1        Q  female     3.0
# 101           Old+65       29.7000        Family_1        C    male     1.0
# 795      Young_18_25        7.2250        Family_1        C    male     3.0
# 1067     Young_18_25        7.7500        Family_1        S  female     3.0
# 290           Old+65       79.6500        Family_2        S    male     1.0
# 1233          Old+65        7.9250        Family_1        S    male     3.0
# 825          Kids-10       46.9000  Family_upper_5        S    male     3.0
# 806      Young_18_25       34.3750      Family_3_5        S  female     3.0
# 1107     Young_18_25        8.6625        Family_1        S    male     3.0
# 1106          Old+65       39.6875      Family_3_5        S  female     3.0
# 76            Old+65       83.1583        Family_2        C  female     1.0
# 516           Old+65       26.0000        Family_2        S    male     2.0
# 1216     Young_18_25        7.7333        Family_1        Q  female     3.0
# 1045  Teenager_10_18        7.7500        Family_1        S    male     3.0
# 68            Old+65       29.7000        Family_1        C    male     1.0
# 228   Teenager_10_18      108.9000        Family_1        C    male     1.0
# 393      Young_18_25       31.5000        Family_1        S    male     2.0
# 178           Old+65       52.5542        Family_1        S  female     1.0
# 1134     Young_18_25        8.6625        Family_1        S    male     3.0
# 1122     Young_18_25       22.3583        Family_2        C  female     3.0
# 13            Old+65       78.8500        Family_1        S  female     1.0
# 731      Young_18_25        7.8958        Family_1        S    male     3.0
# 341   Teenager_10_18       39.0000      Family_3_5        S  female     2.0
#
#      title  is_alone y_true  y_predict  NO_SURVIVED  SURVIVED
# 319    Mrs         1      1          1            0         1
# 1188   Mrs         0      1          1            0         1
# 317     Mr         1      1          1            0         1
# 528     Mr         1      0          0            1         0
# 1046    Mr         1      0          0            1         0
# 603    Mrs         0      1          1            0         1
# 114     Mr         0      0          0            1         0
# 62      Mr         1      0          0            1         0
# 723     Mr         1      0          0            1         0
# 1240    Mr         1      1          1            0         1
# 987    Mrs         1      0          1            0         1
# 507   rare         1      0          0            1         0
# 1250    Mr         1      0          0            1         0
# 1128    Mr         1      0          0            1         0
# 1135    Mr         1      0          0            1         0
# 545    Mrs         0      1          1            0         1
# 909     Mr         1      1          0            1         0
# 123     Mr         0      1          1            0         1
# 623    Mrs         0      0          0            1         0
# 787     Mr         1      0          0            1         0
# 930     Mr         1      0          0            1         0
# 1222    Mr         1      0          0            1         0
# 1059    Mr         1      0          0            1         0
# 999    Mrs         1      1          1            0         1
# 446    Mrs         0      1          1            0         1
# 391     Mr         1      0          0            1         0
# 858     Mr         1      1          1            0         1
# 854     Mr         1      0          0            1         0
# 276     Mr         1      0          0            1         0
# 1304   Mrs         1      0          0            1         0
# 859    Mrs         1      0          0            1         0
# 1123   Mrs         0      1          1            0         1
# 398     Mr         0      1          1            0         1
# 1104    Mr         0      0          0            1         0
# 502    Mrs         1      1          1            0         1
# 926     Mr         1      1          0            1         0
# 635     Mr         1      0          0            1         0
# 651     Mr         1      0          0            1         0
# 947    Mrs         1      1          1            0         1
# 464     Mr         1      0          0            1         0
# 760     Mr         1      1          1            0         1
# 110     Mr         1      0          0            1         0
# 1297    Mr         1      0          0            1         0
# 510     Mr         1      0          0            1         0
# 853     Mr         1      0          0            1         0
# 1178    Mr         0      0          0            1         0
# 367     Mr         1      0          0            1         0
# 95     Mrs         0      1          1            0         1
# 430    Mrs         1      1          1            0         1
# 1001   Mrs         0      1          1            0         1
# 702    Mrs         1      0          0            1         0
# 218   rare         1      1          1            0         1
# 318     Mr         1      0          0            1         0
# 205     Mr         1      0          0            1         0
# 862    Mrs         1      1          1            0         1
# 608     Mr         1      0          0            1         0
# 719     Mr         1      1          1            0         1
# 214    Mrs         1      1          1            0         1
# 137    Mrs         1      1          1            0         1
# 74      Mr         1      0          0            1         0
# 827     Mr         0      0          0            1         0
# 175     Mr         1      0          0            1         0
# 1287    Mr         1      0          0            1         0
# 294     Mr         0      0          0            1         0
# 693     Mr         1      1          1            0         1
# 199   rare         1      1          1            0         1
# 852    Mrs         1      0          0            1         0
# 0      Mrs         1      1          1            0         1
# 1005    Mr         1      0          0            1         0
# 753     Mr         1      0          0            1         0
# 1243    Mr         1      0          0            1         0
# 716     Mr         1      0          0            1         0
# 482    Mrs         1      1          1            0         1
# 915     Mr         1      0          0            1         0
# 58      Mr         1      0          0            1         0
# 500     Mr         1      0          0            1         0
# 402    Mrs         1      1          1            0         1
# 710    Mrs         1      0          0            1         0
# 101     Mr         1      0          0            1         0
# 795     Mr         1      0          0            1         0
# 1067   Mrs         1      1          1            0         1
# 290     Mr         0      0          0            1         0
# 1233    Mr         1      1          1            0         1
# 825     Mr         0      0          0            1         0
# 806    Mrs         0      0          0            1         0
# 1107    Mr         1      0          0            1         0
# 1106   Mrs         0      0          0            1         0
# 76     Mrs         0      1          1            0         1
# 516     Mr         0      0          0            1         0
# 1216   Mrs         1      1          1            0         1
# 1045    Mr         1      0          0            1         0
# 68      Mr         1      1          1            0         1
# 228     Mr         1      0          0            1         0
# 393     Mr         1      0          0            1         0
# 178    Mrs         1      1          1            0         1
# 1134    Mr         1      0          0            1         0
# 1122   Mrs         0      1          1            0         1
# 13     Mrs         1      1          1            0         1
# 731     Mr         1      0          0            1         0
# 341    Mrs         0      1          1            0         1
